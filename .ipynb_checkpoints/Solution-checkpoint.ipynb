# %%
# all imports I need
import pandas as pd
import numpy as np
import seaborn as sbs
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
#models
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

import seaborn as sns
import matplotlib as mplt
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load data

# %%
TRAIN_PATH = "train.csv"
TEST_PATH = 'test.csv'
Full_train = pd.read_csv(TRAIN_PATH,index_col='Id')
Full_test = pd.read_csv(TEST_PATH)
Full_train.dropna(axis=0,subset=['SalePrice'], inplace=True)
y_full = Full_train.SalePrice
X_full = Full_train.drop(axis=1, columns=['SalePrice'])

# %%
Full_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
numeric_col = list((X_full.select_dtypes(exclude='object')).columns)
string_col = list((X_full.select_dtypes(include='object')).columns)
low_categorical_col = [col for col in X_full.columns
                  if X_full[col].dtype == 'object' and X_full[col].nunique() <10]

# %%
X_full.shape
# Out:
# (1460, 79)

# %% [markdown]
# # Look inside data

# %% [markdown]
# ## explore data

# %% [markdown]
# ### numeric data

# %%
for col in numeric_col:
    sns.displot( X_full, x=col)
# Out:
# /home/leo/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:392: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)

# %% [markdown]
# ### numeric cols with correlation

# %%
numeric_col_corr = []
for col in numeric_col:
    corr = X_full[col].corr(y_full)
    numeric_col_corr.append((col, corr))
numeric_col_corr.sort(key=lambda x:x[1], reverse=True)

# %%
numeric_col_corr[:10]
# Out:
# [('OverallQual', 0.7909816005838047),
#  ('GrLivArea', 0.7086244776126522),
#  ('GarageCars', 0.6404091972583531),
#  ('GarageArea', 0.6234314389183617),
#  ('TotalBsmtSF', 0.6135805515591954),
#  ('1stFlrSF', 0.6058521846919148),
#  ('FullBath', 0.5606637627484456),
#  ('TotRmsAbvGrd', 0.5337231555820284),
#  ('YearBuilt', 0.5228973328794969),
#  ('YearRemodAdd', 0.5071009671113865)]

# %%
numeric_col_corr[-10:]
# Out:
# [('3SsnPorch', 0.04458366533574845),
#  ('BsmtFinSF2', -0.011378121450215136),
#  ('BsmtHalfBath', -0.016844154297359023),
#  ('MiscVal', -0.021189579640303248),
#  ('LowQualFinSF', -0.025606130000679586),
#  ('YrSold', -0.028922585168730343),
#  ('OverallCond', -0.07785589404867801),
#  ('MSSubClass', -0.08428413512659526),
#  ('EnclosedPorch', -0.1285779579259565),
#  ('KitchenAbvGr', -0.1359073708421411)]

# %%
numeric_corr_cols = [ col_name[0] for col_name in numeric_col_corr[:10]]
numeric_corr_cols
# Out:
# ['OverallQual',
#  'GrLivArea',
#  'GarageCars',
#  'GarageArea',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'YearBuilt',
#  'YearRemodAdd']

# %%
# No any nans in selected columns
X_full[numeric_corr_cols].isna().any()
# Out:
# OverallQual     False
# GrLivArea       False
# GarageCars      False
# GarageArea      False
# TotalBsmtSF     False
# 1stFlrSF        False
# FullBath        False
# TotRmsAbvGrd    False
# YearBuilt       False
# YearRemodAdd    False
# dtype: bool

# %%
for col in numeric_corr_cols:
    sns.displot(X_full, x=col)

# %% [markdown]
# ### object (string) data

# %%
for col in X_full[string_col].dropna(axis=1).columns:
    sns.displot( X_full, x=col)
# Out:
# /home/leo/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:392: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)

# %% [markdown]
# ## Find problems inside data

# %% [markdown]
# ### find Nan

# %%
miss_cols = [col for col in X_full.columns
            if X_full[col].isna().any()]
miss_cols
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
missing_val_count_by_column = X_full[miss_cols].isna().sum()
print(missing_val_count_by_column)
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# ### Generalize data( find too big or too small)

# %%
# find outliers
# it is very strong assumption that every feature is belong to normal distribution,
# but actually, it is not true( this can be seen in graphics), so I need
# much more sophisticated algorithms to find outliers, but for now I assume
# that every feature is belong to normal dist. It is known, that 99.7% of X 
# within range mean + 3 * std. I use this property to find extreme values
outlier_threshold = abs(X_full[numeric_col].mean()) + abs(3*X_full[numeric_col].std())
outlier_threshold
# Out:
# MSSubClass         183.798973
# LotFrontage        142.904214
# LotArea          40460.622879
# OverallQual         10.248305
# OverallCond          8.913740
# YearBuilt         2061.876520
# YearRemodAdd      2046.801974
# MasVnrArea         646.883881
# BsmtFinSF1        1811.933999
# BsmtFinSF2         530.507133
# BsmtUnfSF         1892.841277
# TotalBsmtSF       2373.545425
# 1stFlrSF          2322.389926
# 2ndFlrSF          1656.577773
# LowQualFinSF       151.713765
# GrLivArea         3091.904849
# BsmtFullBath         1.982074
# BsmtHalfBath         0.773792
# FullBath             3.217816
# HalfBath             1.891533
# BedroomAbvGr         5.313772
# KitchenAbvGr         1.707590
# TotRmsAbvGrd        11.393988
# Fireplaces           2.547013
# GarageYrBlt       2052.575338
# GarageCars           4.009068
# GarageArea        1114.394661
# WoodDeckSF         470.260904
# OpenPorchSF        245.428357
# EnclosedPorch      205.311555
# 3SsnPorch           91.361581
# ...

# %%
# drop outliers
X_full[numeric_col][X_full[numeric_col] <= outlier_threshold]
X_numeric_cols_without_outliers = X_full[numeric_col][abs(X_full[numeric_col]) <= outlier_threshold].dropna()
X_numeric_cols_without_outliers
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1           60.0         65.0   8450.0            7          5.0       2003
# 3           60.0         68.0  11250.0            7          5.0       2001
# 5           60.0         84.0  14260.0            8          5.0       2000
# 7           20.0         75.0  10084.0            8          5.0       2004
# 11          20.0         70.0  11200.0            5          5.0       1965
# ...          ...          ...      ...          ...          ...        ...
# 1452        20.0         78.0   9262.0            8          5.0       2008
# 1453       180.0         35.0   3675.0            5          5.0       2005
# 1455        20.0         62.0   7500.0            7          5.0       2004
# 1456        60.0         62.0   7917.0            6          5.0       1999
# 1457        20.0         85.0  13175.0            6          6.0       1978
#
# ...

# %% [markdown]
# ## preprocessing

# %% [markdown]
# ### numeric

# %% [markdown]
# #### dropna

# %%
X_numeric = X_full[numeric_col]
X_numeric = X_numeric.dropna()
y_numeric = pd.Series(y_full, index=X_numeric.index)

# %%
X_numeric.shape[0] == y_numeric.shape[0]
# Out:
# True

# %%
X_numeric
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1             60         65.0     8450            7            5       2003
# 2             20         80.0     9600            6            8       1976
# 3             60         68.0    11250            7            5       2001
# 4             70         60.0     9550            7            5       1915
# 5             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1456          60         62.0     7917            6            5       1999
# 1457          20         85.0    13175            6            6       1978
# 1458          70         66.0     9042            7            9       1941
# 1459          20         68.0     9717            5            6       1950
# 1460          20         75.0     9937            5            6       1965
#
# ...

# %%
y_numeric.shape
# Out:
# (1121,)

# %% [markdown]
# ##### all numeric cols

# %%
X_train, X_valid, y_train, y_valid =  train_test_split(X_numeric, y_numeric, random_state=42)

# %%
#model = DecisionTreeRegressor(random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
prediction = model.predict(X_valid)
mse = mean_squared_error(prediction, y_valid)
mae = mean_absolute_error(prediction, y_valid)
print(mse)
print(mae)
# Out:
# 1468737558.144131
# 23526.480472922958

# %% [markdown]
# ### numeric cols without outliers

# %%
X_numeric_cols_without_outliers.shape
# Out:
# (804, 36)

# %%
y_numeric_without_outliers = pd.Series(y_full, index=X_numeric_cols_without_outliers.index)
y_numeric_without_outliers.shape
# Out:
# (804,)

# %%
X_train, X_valid, y_train, y_valid =  train_test_split(X_numeric_cols_without_outliers,
                                                       y_numeric_without_outliers, random_state=42)

# %%
#model = DecisionTreeRegressor(random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
prediction = model.predict(X_valid)
mse = mean_squared_error(prediction, y_valid)
mae = mean_absolute_error(prediction, y_valid)
print(mse)
print(mae)
# Out:
# 671318076.5376849
# 19305.982956481883

# %% [markdown]
# ### X with good enough corr

# %%
X_numeric_corr = X_full[numeric_corr_cols]
X_numeric_corr.shape
# Out:
# (1460, 10)

# %%
X_train, X_valid, y_train, y_valid =  train_test_split(X_numeric_corr, y_full, random_state=42)

# %%
#model = DecisionTreeRegressor(random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
prediction = model.predict(X_valid)
mse = mean_squared_error(prediction, y_valid)
mae = mean_absolute_error(prediction, y_valid)
print(mse)
print(mae)
# Out:
# 1401043190.1361732
# 24242.136959383708

# %% [markdown]
# ### corr without outliers

# %%
outlier_threshold = X_numeric_corr.mean() + 3*X_numeric_corr.std()
outlier_threshold
# Out:
# OverallQual       10.248305
# GrLivArea       3091.904849
# GarageCars         4.009068
# GarageArea      1114.394661
# TotalBsmtSF     2373.545425
# 1stFlrSF        2322.389926
# FullBath           3.217816
# TotRmsAbvGrd      11.393988
# YearBuilt       2061.876520
# YearRemodAdd    2046.801974
# dtype: float64

# %%
X_numeric_corr[X_numeric_corr <= outlier_threshold]['GarageArea'].isna()[X_numeric_corr[X_numeric_corr <= outlier_threshold]['GarageArea'].isna()]
X_numeric_corr_without_outliers = X_numeric_corr[X_numeric_corr <= outlier_threshold].dropna()

# %%
X_numeric_corr_without_outliers.shape
# Out:
# (1422, 10)

# %%
y_corr_without_outliers = pd.Series(y_full, index=X_numeric_corr_without_outliers.index)
y_corr_without_outliers.shape
# Out:
# (1422,)

# %%
X_train, X_valid, y_train, y_valid =  train_test_split(X_numeric_corr_without_outliers, y_corr_without_outliers, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
prediction = model.predict(X_valid)
mse = mean_squared_error(prediction, y_valid)
mae = mean_absolute_error(prediction, y_valid)
print(mse)
print(mae)
# Out:
# 900020576.7657244
# 22205.802305748166

# %% [markdown]
# # Create sumbission on kaggle

# %%
#sumbission on Kaggle
#predict_on_test = model.predict(X_exam)
#output = pd.DataFrame({'Id': Full_test.Id,
#                       'SalePrice': predict_on_test})
#output.to_csv('submission.csv', index=False)
